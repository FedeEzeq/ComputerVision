# %%
#Si queremos que las imágenes sean mostradas en una ventana emergente quitar el inline
# %matplotlib inline

# OpenCV-Python utiliza NumPy para el manejo de imágenes
import numpy as np
# cv2 es el módulo python para acceder a OpenCV 
import cv2 as cv
# Usamos las poderosas herramientas de graficación de matplotlib para mostrar imágenes, perfiles, histogramas, etc
import matplotlib.pyplot as plt

# %%
#IMAGEN 1
img_tito_1 = cv.imread('WP_R.png')
print (img_tito_1.shape)
imgRGB1 = cv.cvtColor(img_tito_1,cv.COLOR_BGR2RGB)
#plt.imshow(imgRGB1)

#split a los colores
im_r,im_g,im_b = cv.split(imgRGB1)
print(im_r.shape)

#print(im_r)
#print ("-------------------------")
#print(im_g)
#print ("-------------------------")
#print(im_b)
# Out:
# (565, 565, 3)
# (565, 565)

# %%
#BUSCO EL MÁXIMO DE CADA COLOR

#opcion 1 - por qué no funciona?
#RED
mat_flattened_r = im_r.flatten()
max_val_r = max(mat_flattened)
#print (max_val_r)
#GREEN
mat_flattened_g = im_g.flatten()
max_val_g = max(mat_flattened)
#print (max_val_g)
#BLUE
mat_flattened_b = im_b.flatten()
max_val_b = max(mat_flattened)
#print (max_val_b)

#opcion 2 ELEGIDA
#red
big_array = []              #que hace esto? 
for a in im_r:
   big_array.extend(a)
max_r = max(big_array)
print ('maximo rojo: ', max_r)
#green
big_array = []              
for a in im_g:
   big_array.extend(a)
max_g = max(big_array)
print ('maximo verde: ', max_g)
#blue
big_array = []              
for a in im_b:
   big_array.extend(a)
max_b = max(big_array)
print ('maximo azul: ', max_b)
# Out:
# maximo rojo:  208
# maximo verde:  47
# maximo azul:  173

# %%
#NORMALIZO CADA CANAL

#Canal Rojo
im_r_norm = im_r * 255 / max_r
#print ('shape: ',im_r_norm.shape)
#print (im_r_norm)

#Canal Verde
im_g_norm = im_g * 255 / max_g

#Canal Rojo
im_b_norm = im_b * 255 / max_b

# %%
#JUNTO LOS 3 CANALES EN UNA MISMA MATRIZ Y ARMO IMAGEN

imgRGB2 = cv.merge((im_r_norm,im_g_norm,im_b_norm))
plt.imshow(imgRGB2)
plt.show()
# Out:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
